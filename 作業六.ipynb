# %% [markdown]
# <a href="https://colab.research.google.com/github/ChangWei614/2025fin/blob/main/%E4%BD%9C%E6%A5%AD%E5%85%AD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url1 = 'https://raw.githubusercontent.com/miiiike25/2025fin/refs/heads/main/TSMC.csv'
url2 = 'https://raw.githubusercontent.com/hsu1028/hw6/refs/heads/main/%E7%87%A6%E5%9D%A4.xls'
df1 = pd.read_csv(url1)
# df['Open']  # 開盤價
# df['Close'] # 收盤價
df1['Close'] = df1['Close'].iloc[2:].reset_index(drop=True)
for i in range(len(df1['Close'])):
  print('從2025年起2330.TW在第',i+1,'個交易日的收盤價為',df1['Close'][i])

df1['Close'] = df1['Close'].iloc[2:].reset_index(drop=True)
for i in range(len(df1['Close'])):
  print('從2025年起2330.TW在第',i+1,'個交易日的收盤價為',df1['Close'][i])

df2 = pd.read_csv(url2)

df2['Close'] = df2['Close'].iloc[2:].reset_index(drop=True)
for i in range(len(df2['Close'])-2):
  print('從2025年起2430.TW在第',i+1,'個交易日的收盤價為',df2['Close'][i])
# Out:
# 從2025年起2330.TW在第 1 個交易日的收盤價為 1060.0592041015625
# 從2025年起2330.TW在第 2 個交易日的收盤價為 1070.0128173828125
# 從2025年起2330.TW在第 3 個交易日的收盤價為 1119.7808837890625
# 從2025年起2330.TW在第 4 個交易日的收盤價為 1124.7576904296875
# 從2025年起2330.TW在第 5 個交易日的收盤價為 1099.8736572265625
# 從2025年起2330.TW在第 6 個交易日的收盤價為 1094.8968505859375
# 從2025年起2330.TW在第 7 個交易日的收盤價為 1094.8968505859375
# 從2025年起2330.TW在第 8 個交易日的收盤價為 1070.0128173828125
# 從2025年起2330.TW在第 9 個交易日的收盤價為 1084.9432373046875
# 從2025年起2330.TW在第 10 個交易日的收盤價為 1060.0592041015625
# 從2025年起2330.TW在第 11 個交易日的收盤價為 1099.8736572265625
# 從2025年起2330.TW在第 12 個交易日的收盤價為 1114.8040771484375
# 從2025年起2330.TW在第 13 個交易日的收盤價為 1114.8040771484375
# 從2025年起2330.TW在第 14 個交易日的收盤價為 1114.8040771484375
# 從2025年起2330.TW在第 15 個交易日的收盤價為 1129.7344970703125
# 從2025年起2330.TW在第 16 個交易日的收盤價為 1065.0360107421875
# 從2025年起2330.TW在第 17 個交易日的收盤價為 1089.9200439453125
# 從2025年起2330.TW在第 18 個交易日的收盤價為 1104.8504638671875
# 從2025年起2330.TW在第 19 個交易日的收盤價為 1109.8272705078125
# ...
