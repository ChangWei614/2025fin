# %%
import pandas as pd 
import yfinance as yf
df = yf.download('2454.TW',start = '2025-01-01',end = '2025-03-31') # 2454.TW的股價資料
df
# df['Close']['2454.TW']
# for i in range(len(df['Close']['2454.TW'])):
#     print('從2025年起，第',len(df['Close']['2454.TW'])-i,'個交易日的收盤價格為：',df['Close']['2454.TW'][i])
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price        Close    High     Low    Open    Volume
# Ticker     2454.TW 2454.TW 2454.TW 2454.TW   2454.TW
# Date
# 2025-01-02  1350.0  1400.0  1335.0  1395.0   6820305
# 2025-01-03  1365.0  1370.0  1335.0  1365.0   5752498
# 2025-01-06  1425.0  1425.0  1390.0  1390.0   6907233
# 2025-01-07  1490.0  1500.0  1415.0  1445.0  12307998
# 2025-01-08  1470.0  1500.0  1460.0  1500.0  10805038
# 2025-01-09  1440.0  1480.0  1440.0  1470.0   7021298
# 2025-01-10  1465.0  1495.0  1445.0  1460.0   7157266
# 2025-01-13  1390.0  1460.0  1385.0  1435.0   9742772
# 2025-01-14  1400.0  1415.0  1380.0  1385.0   5279672
# 2025-01-15  1420.0  1445.0  1390.0  1390.0   6417175
# 2025-01-16  1460.0  1470.0  1430.0  1450.0   7314623
# 2025-01-17  1430.0  1455.0  1420.0  1450.0   5488719
# 2025-01-20  1445.0  1455.0  1425.0  1425.0   3956489
# 2025-01-21  1465.0  1475.0  1435.0  1440.0   4428280
# ...
